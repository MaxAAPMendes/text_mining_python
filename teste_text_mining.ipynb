# %% [markdown]
# <h2 style="color: #696969">Test Text Mining</h2>

# %% [markdown]
# <h3 style="color: blue">1. Import Pandas</3>

# %%
import pandas as pd

# %% [markdown]
# <h3 style="color: blue">2. Open the Data Base File</h3>

# %%
db = pd.read_excel('L:\Interna\Informações Gerencias\Projetos e Pesquisas\Machine Learning\dados2.xlsx')

# %%
type(db)
# Out:
# pandas.core.frame.DataFrame

# %%
db.head()
# Out:
#    evento  valor                                      justificativa  \
# 0    1615  525.0  - MANUTENCAO DE 07 CADEIRAS EXISTENTES NA FILA...
# 1     233  680.0  PAGAMENTO INSTALÇAO PLACAS BIOMBO PRIVATICIDAD...
# 2     233   56.8    01 ASSENTO SANITARIO, PARA O BANHEIRO FEMININO.
# 3     233   30.0                01 PINO/REFORçO ESTAçãO DE TRABALHO
# 4    1615  995.0  02 CADEIRAS MOON (GRAMPEAGEM); 03 CADEIRAS ESP...
#
#      deferimento_justificativa  Deferido?
# 0  Pedido deferido pelo gestor          1
# 1  Pedido deferido pelo gestor          1
# 2  Pedido deferido pelo gestor          1
# 3  Pedido deferido pelo gestor          1
# 4  Pedido deferido pelo gestor          1

# %%
db.count()
# Out:
# evento                       4711
# valor                        4711
# justificativa                4711
# deferimento_justificativa    4711
# Deferido?                    4711
# dtype: int64

# %% [markdown]
# <h3 style="color: blue">3. Text mining</h3>

# %%
db['justificativa'].head()
# Out:
# 0    - MANUTENCAO DE 07 CADEIRAS EXISTENTES NA FILA...
# 1    PAGAMENTO INSTALÇAO PLACAS BIOMBO PRIVATICIDAD...
# 2      01 ASSENTO SANITARIO, PARA O BANHEIRO FEMININO.
# 3                  01 PINO/REFORçO ESTAçãO DE TRABALHO
# 4    02 CADEIRAS MOON (GRAMPEAGEM); 03 CADEIRAS ESP...
# Name: justificativa, dtype: object

# %%
type(db['justificativa'][0])
# Out:
# str

# %%
db['num_carcteres'] = db['justificativa'].str.len()

# %%
db.head()
# Out:
#    evento  valor                                      justificativa  \
# 0    1615  525.0  - MANUTENCAO DE 07 CADEIRAS EXISTENTES NA FILA...
# 1     233  680.0  PAGAMENTO INSTALÇAO PLACAS BIOMBO PRIVATICIDAD...
# 2     233   56.8    01 ASSENTO SANITARIO, PARA O BANHEIRO FEMININO.
# 3     233   30.0                01 PINO/REFORçO ESTAçãO DE TRABALHO
# 4    1615  995.0  02 CADEIRAS MOON (GRAMPEAGEM); 03 CADEIRAS ESP...
#
#      deferimento_justificativa  Deferido?  num_carcteres
# 0  Pedido deferido pelo gestor          1            115
# 1  Pedido deferido pelo gestor          1             56
# 2  Pedido deferido pelo gestor          1             47
# 3  Pedido deferido pelo gestor          1             35
# 4  Pedido deferido pelo gestor          1            202

# %% [markdown]
# <h2>Removing Numbers</h2>

# %%
db['justificativa'][0].split()
# Out:
# ['-',
#  'MANUTENCAO',
#  'DE',
#  '07',
#  'CADEIRAS',
#  'EXISTENTES',
#  'NA',
#  'FILA',
#  'DE',
#  'ESPERA',
#  'CAIXA/ATEND',
#  'E',
#  '03',
#  'CADEIRAS',
#  'DE',
#  'USO',
#  'DOS',
#  'FUNCIS',
#  'DO',
#  'ATENDIMENTO']

# %%
# DEU CERTO -----------
#line_number = []
#for x in db['justificativa'][0].split():
#    if not x.isdigit():
#        print(x)
#        line_number.append(x)
#print(line_number)
y=''
for x in db['justificativa'][0].split():
    #db['justificativa_limpa'][0] = db['justificativa'][0].apply(lambda x: x for x in x.split() if x.isdigit())
    if not x.isdigit():
        y += x + " "

print(y)
# Out:
# - MANUTENCAO DE CADEIRAS EXISTENTES NA FILA DE ESPERA CAIXA/ATEND E CADEIRAS DE USO DOS FUNCIS DO ATENDIMENTO

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
db['justificativa'][0] = y
# Out:
# C:\Users\f7098849\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
db['justificativa'][0]
# Out:
# '- MANUTENCAO DE CADEIRAS EXISTENTES NA FILA DE ESPERA CAIXA/ATEND E CADEIRAS DE USO DOS FUNCIS DO ATENDIMENTO '

# %% [markdown]
# <h2>Removing stopwords</h>

# %%
stop = pd.read_excel('L:\Interna\Informações Gerencias\Projetos e Pesquisas\Machine Learning\Stopwords\stopwords.xlsx', sheet_name = 'Planilha1')

# %%
stop.head()
# Out:
#      stop
# 0       a
# 1  acerca
# 2   adeus
# 3   agora
# 4   ainda

# %%
print(stop['stop'].head())
# Out:
# 0         a
# 1    acerca
# 2     adeus
# 3     agora
# 4     ainda
# Name: stop, dtype: object

# %%
db['justificativa'][0] = db['justificativa'][0].lower()

db['justificativa'][0]
# Out:
# C:\Users\f7098849\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# '- manutencao de cadeiras existentes na fila de espera caixa/atend e cadeiras de uso dos funcis do atendimento '

# %%
for x in stop['stop']:
    print(x)
# Out:
# a
# acerca
# adeus
# agora
# ainda
# alem
# algmas
# algo
# algumas
# alguns
# ali
# além
# ambas
# ambos
# ano
# anos
# antes
# ao
# aonde
# aos
# apenas
# apoio
# apontar
# apos
# após
# aquela
# aquelas
# aquele
# aqueles
# aqui
# aquilo
# as
# assim
# através
# atrás
# até
# aí
# baixo
# bastante
# bem
# boa
# boas
# bom
# bons
# breve
# cada
# caminho
# catorze
# cedo
# cento
# certamente
# certeza
# cima
# cinco
# coisa
# com
# como
# comprido
# conhecido
# conselho
# contra
# contudo
# corrente
# cuja
# cujas
# cujo
# cujos
# custa
# cá
# da
# daquela
# daquelas
# daquele
# daqueles
# dar
# das
# de
# debaixo
# dela
# delas
# dele
# deles
# demais
# dentro
# depois
# desde
# desligado
# dessa
# dessas
# desse
# desses
# desta
# destas
# deste
# destes
# deve
# devem
# deverá
# dez
# dezanove
# dezasseis
# dezassete
# dezoito
# dia
# diante
# direita
# dispoe
# dispoem
# diversa
# diversas
# diversos
# diz
# dizem
# dizer
# do
# dois
# dos
# doze
# duas
# durante
# dá
# dão
# ...

# %%
#removingo stopwords
#db['justificativa'] = db['justificativa'].apply(lambda x: "*".join(x for x in x.split() if x not in stop))
#db['justificativa'][0]

# %%
type(stop['stop'])
# Out:
# pandas.core.series.Series

# %%
x = 'acerca'

for y in stop['stop']:
    if x == y:
        print('tá lá')
        print('*******')
        print(y)
        type(y)
    
x
type(x)
# Out:
# tá lá
# *******
# acerca
# str

# %%
nova = ''
sobra = ''
for x in db['justificativa'][0].split():
    #print(x)
    for y in stop['stop']:
        if x !=y:
            if x not in nova.split(' '):
                nova += x+" "
        else:
            sobra += x
    
print(nova)
print(sobra)
# Out:
# - manutencao de cadeiras existentes na fila espera caixa/atend e uso dos funcis do atendimento
# denadeededosdo

# %%
#removing stopwords workit
semStop = ''
for x in db['justificativa'][0].split():
    if x not in list(stop['stop']):
        #print(x)
        semStop += x + " "
print(semStop)
# Out:
# - manutencao cadeiras existentes fila espera caixa/atend cadeiras uso funcis atendimento

# %%
db['justificativa'][0] = semStop
print(db['justificativa'][0])
type(db['justificativa'][0])
# Out:
# - manutencao cadeiras existentes fila espera caixa/atend cadeiras uso funcis atendimento
# C:\Users\f7098849\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# str

# %% [markdown]
# <h2>Removing special Characters<h2>

# %%
semSPC = ' '
for spc in db['justificativa'][0].split():
    if spc.isalpha():
        #print(spc)
        semSPC += spc + " "
print(semSPC)
# Out:
#  manutencao cadeiras existentes fila espera cadeiras uso funcis atendimento

# %%
db['justificativa'][0] = semSPC
print(db['justificativa'][0])
type(db['justificativa'][0])
# Out:
#  manutencao cadeiras existentes fila espera cadeiras uso funcis atendimento
# C:\Users\f7098849\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# str

# %% [markdown]
# <h2>Removing Ponctuation</h2>

# %%
db['justificativa'].head()
# Out:
# 0     manutencao cadeiras existentes fila espera ca...
# 1    PAGAMENTO INSTALÇAO PLACAS BIOMBO PRIVATICIDAD...
# 2      01 ASSENTO SANITARIO, PARA O BANHEIRO FEMININO.
# 3                  01 PINO/REFORçO ESTAçãO DE TRABALHO
# 4    02 CADEIRAS MOON (GRAMPEAGEM); 03 CADEIRAS ESP...
# Name: justificativa, dtype: object

# %%
db['justificativa'] = db['justificativa'].str.replace('[^\w\s]','')

# %%
db['justificativa'].head()
# Out:
# 0     manutencao cadeiras existentes fila espera ca...
# 1    PAGAMENTO INSTALÇAO PLACAS BIOMBO PRIVATICIDAD...
# 2        01 ASSENTO SANITARIO PARA O BANHEIRO FEMININO
# 3                   01 PINOREFORçO ESTAçãO DE TRABALHO
# 4    02 CADEIRAS MOON GRAMPEAGEM 03 CADEIRAS ESPALD...
# Name: justificativa, dtype: object

# %% [markdown]
# <h2>Removing Acentos<h2>

# %%
db['justificativa'].head()
# Out:
# 0     manutencao cadeiras existentes fila espera ca...
# 1    PAGAMENTO INSTALÇAO PLACAS BIOMBO PRIVATICIDAD...
# 2        01 ASSENTO SANITARIO PARA O BANHEIRO FEMININO
# 3                   01 PINOREFORçO ESTAçãO DE TRABALHO
# 4    02 CADEIRAS MOON GRAMPEAGEM 03 CADEIRAS ESPALD...
# Name: justificativa, dtype: object

# %%
#import re

# %%
#texto = 'novo texto para - testar o que é carcter/ASD # especial;/_ saúde VAZA'

# %%
#import re
#import re
#texto = 'novo texto para - testar o que é carcter # especial;/_ saúde'
#string_nova = re.sub(u'[^a-zA-Z0-9áéíóúÁÉÍÓÚâêîôÂÊÎÔãõÃÕçÇ: ]', '', texto)
#print(string_nova)

# %%
#padrao = "[^a-zA-Z0-9_]"
#texto =texto.replace('[^\w\s]', '*')
#print(texto)

# %%
import unicodedata

# %%
db['justificativa'][3] = ''.join(ch for ch in unicodedata.normalize('NFKD',db['justificativa'][3])
                                 if not unicodedata.combining(ch))
# Out:
# C:\Users\f7098849\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
db['justificativa'][3]
# Out:
# '01 PINOREFORcO ESTAcaO DE TRABALHO'

# %%
#DEU CERTO
#import re
#import unicodedata
#def removerAcentosECaracteresEspeciais(palavra):
    # Unicode normalize transforma um caracter em seu equivalente em latin.
#    nfkd = unicodedata.normalize('NFKD', palavra)
    #alavraSemAcento = u"".join([c for c in nfkd if not unicodedata.combining(c)])
    # Usa expressão regular para retornar a palavra apenas com números, letras e espaço
    #eturn re.sub('[^a-zA-Z0-9 \\\]', '', palavraSemAcento)
#alavra = 'saúde'
#avrasemacento = removerAcentosECaracteresEspeciais(palavra)
#rint(pavrasemacento)

# %% [markdown]
# <h2>Common words<h2>

# %%
commonWords = pd.Series(' '.join(db['justificativa']).split()).value_counts()[:]

# %%
print(commonWords)
# Out:
# DE                   9338
# E                    2667
# DA                   2136
# PARA                 1873
# CADEIRAS             1866
# DO                   1625
# A                    1367
# EM                   1175
# COM                   922
# CONSERTO              860
# ATENDIMENTO           839
# TROCA                 681
# QUE                   653
# AGENCIA               617
# NA                    606
# REPARO                581
# REFERENTE             560
# MANUTENçãO            558
# NO                    549
# DOS                   520
# REFORMA               488
# O                     487
# REF                   454
# DAS                   452
# AGêNCIA               438
# CLIENTES              403
# CAIXA                 328
# VALOR                 325
# IMPORTE               294
# PEDIDO                294
#                      ...
# BALANCANDO              1
# ACONDICIONADO           1
# SOLICITAçOES            1
# 2014                    1
# ...

# %%
#outra opção para contar as palavras
from collections import Counter

# %%
for x in db['justificativa']:
    print(Counter(x.split()))
# Out:
# Counter({'cadeiras': 2, 'manutencao': 1, 'existentes': 1, 'fila': 1, 'espera': 1, 'uso': 1, 'funcis': 1, 'atendimento': 1})
# Counter({'PAGAMENTO': 1, 'INSTALÇAO': 1, 'PLACAS': 1, 'BIOMBO': 1, 'PRIVATICIDADEPINTURA': 1})
# Counter({'01': 1, 'ASSENTO': 1, 'SANITARIO': 1, 'PARA': 1, 'O': 1, 'BANHEIRO': 1, 'FEMININO': 1})
# Counter({'01': 1, 'PINOREFORcO': 1, 'ESTAcaO': 1, 'DE': 1, 'TRABALHO': 1})
# Counter({'CADEIRAS': 3, 'ESPALDAR': 3, 'MEDIO': 2, '01': 2, 'DE': 2, '02': 1, 'MOON': 1, 'GRAMPEAGEM': 1, '03': 1, 'ESTOFAMEN': 1, 'TO': 1, '04': 1, 'BAIXO': 1, 'ESTOFAMENTO': 1, 'CADEIRA': 1, 'APROXIMACAO': 1, 'SOLDAGEM': 1, 'RODIZIO': 1, 'FIXACAO': 1, 'ENCOSTO': 1})
# Counter({'DA': 2, '3130': 2, '02': 1, 'DOBRADIçAS': 1, 'PARA': 1, 'O': 1, 'ARMáRIO': 1, 'DO': 1, 'ALMOX': 1, 'AG': 1, 'MAUNTENçãO': 1, 'DE': 1, 'ARMARIOS': 1, 'GAVETEIROS': 1, 'E': 1, 'MESAS': 1, 'AGêNCIA': 1, 'GLORIA': 1, 'PEçAS': 1, 'COMPLEMENTO': 1, 'AO': 1, 'PEDIDO': 1, '80477147': 1, 'APROVADO': 1})
# ...

# %%
x = pd.get_dummies(db['justificativa'][0])
db['justificativa']
x
# Out:
#     manutencao cadeiras existentes fila espera cadeiras uso funcis atendimento
# 0                                                  1

# %% [markdown]
# <h2>Tokenization</h2>

# %%
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-51-beb514e823a4> in <module>
# ----> 1 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'
